# %%
import numpy as np
import pandas as pd

# %%
def convert_dtype(df):
    df[df.columns[1:]] = df[df.columns[1:]].astype("float64")
    return df

data_path = r"./data/raw_data.xlsx"
na_values = ["b.d", "bdl", "b.d.l.", "BDL", "<LOD", "-", "b.d.l", "n.d.", "bdl "]
raw_df = pd.read_excel(data_path, na_values=na_values)
raw_df
# Out:
#             Deposit type        Co       Ni      Cu     Zn     As     Se  \
# 0                    IOA  18100.00      NaN    6.65    100    1.1    NaN
# 1                    IOA  14700.00      NaN    8.72    100    1.8    NaN
# 2                    IOA    730.00      NaN    2930   9030   10.0    290
# 3                    IOA   2900.00  8200.00    0.11    100   10.0     85
# 4                    IOA   4100.00   400.00    1100    100   10.0    NaN
# ...                  ...       ...      ...     ...    ...    ...    ...
# 3279  Sedimentary pyrite     40.58   408.21  274.32  18.48  450.0  215.5
# 3280  Sedimentary pyrite     40.45   496.73  323.15  78.05  582.7  270.5
# 3281  Sedimentary pyrite     40.80   503.28  285.82  28.74  475.2  258.2
# 3282  Sedimentary pyrite     49.32   454.38  338.29  60.71  686.8  274.8
# 3283  Sedimentary pyrite     12.83   165.54  302.55  24.34  678.0   34.7
#
#           Ag      Sb    Te     Au       Pb    Bi
# 0        NaN     NaN  0.33   0.19      NaN   NaN
# 1        NaN     NaN  0.55   0.23      NaN   NaN
# 2        1.2    8.18   420   0.17      663   NaN
# 3        NaN    0.04  0.04   0.05      100   NaN
# 4        100     100   0.9   0.26      200   NaN
# ...      ...     ...   ...    ...      ...   ...
# 3279  102.51  120.25  0.52  <0.01   679.89  2.77
# 3280  133.98  170.48  0.98  <0.01  1475.52  3.02
# 3281  112.27  132.11  0.75   0.05  1066.09  3.13
# 3282    31.9   116.1  1.45  <0.01   317.07  3.46
# 3283     2.9   40.13  0.31   0.05   170.95  0.43
#
# [3284 rows x 13 columns]

# %%
# 根据具体缺失元素来筛选所需数据
# select_index = list(map(lambda x: not x, raw_df["Ni"].isnull() & raw_df["Se"].isnull()))
# raw_df = raw_df[select_index]

# 根据缺失元素数量来筛选所需数据
allow_null_number = 5
thresh = raw_df.shape[1] - allow_null_number
raw_df_dropna = raw_df.dropna(thresh=thresh)
raw_df_dropna

# %%
df_remove_less = raw_df.replace("<", "", regex=True)
print(df_remove_less)
print(df_remove_less.dtypes)
df_remove_less = convert_dtype(df_remove_less)
print(df_remove_less.dtypes)
# Out:
#     Deposit type            Co           Ni           Cu       Zn  \
# 2            IOA    730.000000          NaN  2930.000000  9030.00
# 3           IOCG  14000.000000     2.400000     0.480000     1.40
# 4  Skarn Cu-(Fe)      1.690000     1.260000     7.050000      NaN
# 5    Orogenic Au     36.562541    47.125287    42.067685      NaN
# 6            VMS    306.000000    72.300000   171.000000  1461.00
# 7            VMS    667.200000   539.100000  3996.000000  5278.00
# 8            VMS      2.900000    29.600000   644.600000     8.00
# 9          SEDEX     54.380000  2262.310000  3590.350000    31.76
#
#             As          Se          Ag      Sb          Te        Au  \
# 2    10.000000  290.000000    1.200000    8.18  420.000000      0.17
# 3    14.000000   68.470000         NaN     NaN    0.198516     0.013
# 4    15.300000    0.770000    3.230000    0.18         NaN      0.05
# 5   105.229273    1.485378   11.594954     NaN   11.320727  1.055383
# 6  1511.000000    5.570000   11.800000  112.00         NaN      0.18
# 7  1512.000000   76.750000  250.100000   93.39  225.800000     1.877
# 8  1214.400000   91.200000   44.000000   25.00    0.400000      0.06
# 9  1371.600000   12.670000   28.850000  250.88         NaN       NaN
#
#             Pb      Bi
# 2   663.000000     NaN
# 3     0.019000    0.01
# 4    13.830000    5.15
# 5    53.101016     NaN
# 6  1695.000000   45.20
# 7   396.900000  142.00
# 8  1266.100000   42.30
# 9  2373.360000     NaN
# Deposit type     object
# Co              float64
# Ni              float64
# Cu              float64
# Zn              float64
# As              float64
# Se              float64
# Ag              float64
# Sb              float64
# Te              float64
# Au               object
# Pb              float64
# Bi              float64
# dtype: object
# Deposit type     object
# Co              float64
# Ni              float64
# Cu              float64
# Zn              float64
# As              float64
# Se              float64
# Ag              float64
# Sb              float64
# Te              float64
# Au              float64
# Pb              float64
# Bi              float64
# dtype: object

# %%
df_replace_less = raw_df.replace("<.*", np.nan, regex=True)
df_replace_less = convert_dtype(df_replace_less)
# print(df_replace_less)
# df_replace_less[df_replace_less["Deposit type"]=="IOA"].mean()
df_groups = df_replace_less.groupby("Deposit type")
df = pd.DataFrame()
for _, group_item in df_groups:
    for col in group_item.columns[1:]:
        group_item[col][group_item[col].isnull()] = group_item[col].mean()
    df = pd.concat([df, group_item], axis=0)
print(df)
# print(df_replace_less)
clean_data_path = "./data/data_clean.csv"
df.to_csv(clean_data_path)
# Out:
#      Deposit type       Co           Ni        Cu      Zn      As          Se  \
# 0             IOA  18100.0  1845.421687     6.650   100.0     1.1  130.582474
# 1             IOA  14700.0  1845.421687     8.720   100.0     1.8  130.582474
# 2             IOA    730.0  1845.421687  2930.000  9030.0    10.0  290.000000
# 3             IOA   2900.0  8200.000000     0.110   100.0    10.0   85.000000
# 4             IOA   4100.0   400.000000  1100.000   100.0    10.0  130.582474
# ...           ...      ...          ...       ...     ...     ...         ...
# 1758          VMS    164.0    35.400000  5979.000   301.4  2001.4  362.300000
# 1759          VMS     55.9    19.500000  1017.100    22.5  2012.6  407.500000
# 1760          VMS    408.9  1482.000000   461.200  3384.0  2013.0  150.400000
# 1761          VMS    741.7   239.800000     9.106  7739.0  2033.0  143.400000
# 1762          VMS    590.0   428.000000   140.000   218.0  2038.0    5.350000
#
#                Ag          Sb      Te     Au           Pb           Bi
# 0       16.953077   26.040091    0.33  0.190   467.226087    18.133056
# 1       16.953077   26.040091    0.55  0.230   467.226087    18.133056
# 2        1.200000    8.180000  420.00  0.170   663.000000    18.133056
# 3       16.953077    0.040000    0.04  0.050   100.000000    18.133056
# 4      100.000000  100.000000    0.90  0.260   200.000000    18.133056
# ...           ...         ...     ...    ...          ...          ...
# 1758  1400.700000   24.000000   77.60  1.810   482.000000   747.500000
# 1759  1362.600000   59.400000   72.20  1.380  1517.000000  1379.100000
# 1760    16.510000    1.910000   60.26  0.100    72.910000     9.762000
# 1761     5.062000    0.609000   11.34  0.166     9.661000     5.734000
# 1762    11.300000  117.000000    2.54  0.340   403.000000    49.700000
#
# [3284 rows x 13 columns]
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4076\3344485432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_item[col][group_item[col].isnull()] = group_item[col].mean()
